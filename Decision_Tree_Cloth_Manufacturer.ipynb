# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
com_data = pd.read_csv('Company_Data.csv')

# %%
com_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
com_data['Sales'].mean()
# Out:
# 7.496325

# %%
com_data['nSal'] = com_data['Sales'].apply(lambda x: 1  if  x >= 7.496   else 0)

# %%
com_data.Sales.value_counts()
# Out:
# 7.80     4
# 6.67     3
# 8.77     3
# 9.32     3
# 5.87     3
#         ..
# 8.89     1
# 13.39    1
# 9.14     1
# 5.07     1
# 9.50     1
# Name: Sales, Length: 336, dtype: int64

# %%
com_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US  nSal
# ...

# %%
com_data.ShelveLoc.unique()
# Out:
# array(['Bad', 'Good', 'Medium'], dtype=object)

# %%
s_loc = { 'Bad': 0,
         'Medium': 1,
        'Good': 2}

# %%
com_data['Ord_Sheloc']= com_data.ShelveLoc.map(s_loc)

# %%
com_data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US  nSal  Ord_Sheloc
# ...

# %%
comp_data_1= pd.get_dummies(com_data['US'], prefix ='US')

# %%
comp_data2= pd.get_dummies(com_data['Urban'], prefix ='Urban')

# %%
com_data= com_data.drop(['US', 'Urban', 'ShelveLoc', 'Sales'], axis=1)

# %%
com_data= pd.concat([com_data,comp_data_1,comp_data2 ],axis=1)

# %%
com_data
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  nSal  \
# 0          138      73           11         276    120   42         17     1
# 1          111      48           16         260     83   65         10     1
# 2          113      35           10         269     80   59         12     1
# 3          117     100            4         466     97   55         14     0
# 4          141      64            3         340    128   38         13     0
# ..         ...     ...          ...         ...    ...  ...        ...   ...
# 395        138     108           17         203    128   33         14     1
# 396        139      23            3          37    120   55         11     0
# 397        162      26           12         368    159   40         18     0
# 398        100      79            7         284     95   50         12     0
# 399        134      37            0          27    120   49         16     1
#
# ...

# %%
cols = com_data.columns.tolist()

# %%
cols
# Out:
# ['CompPrice',
#  'Income',
#  'Advertising',
#  'Population',
#  'Price',
#  'Age',
#  'Education',
#  'nSal',
#  'Ord_Sheloc',
#  'US_No',
#  'US_Yes',
#  'Urban_No',
#  'Urban_Yes']

# %%
com_data.columns= ['Competitor Price ',
 'Income',
 'Advertising',
 'Population',
 'Price',
 'Age',
 'Education',
 'Sale_target',
 'Ord_Sheloc',
 'US_No',
 'US_Yes',
 'Urban_No',
 'Urban_Yes']

# %%
com_data
# Out:
#      Competitor Price   Income  Advertising  Population  Price  Age  \
# 0                  138      73           11         276    120   42
# 1                  111      48           16         260     83   65
# 2                  113      35           10         269     80   59
# 3                  117     100            4         466     97   55
# 4                  141      64            3         340    128   38
# ..                 ...     ...          ...         ...    ...  ...
# 395                138     108           17         203    128   33
# 396                139      23            3          37    120   55
# 397                162      26           12         368    159   40
# 398                100      79            7         284     95   50
# 399                134      37            0          27    120   49
#
#      Education  Sale_target  Ord_Sheloc  US_No  US_Yes  Urban_No  Urban_Yes
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns #for plotting
from sklearn.ensemble import RandomForestClassifier #for the model
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz #plot tree
from sklearn.metrics import roc_curve, auc #for model evaluation
from sklearn.metrics import classification_report #for model evaluation
from sklearn.metrics import confusion_matrix #for model evaluation
from sklearn.model_selection import train_test_split #for data splitting
import eli5 #for purmutation importance
from eli5.sklearn import PermutationImportance
#import shap #for SHAP values
from pdpbox import pdp, info_plots #for partial plots
np.random.seed(123) #ensure reproducibility

pd.options.mode.chained_assignment = None  #hide any pandas warnings
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
com_data.dtypes
# Out:
# Competitor Price     int64
# Income               int64
# Advertising          int64
# Population           int64
# Price                int64
# Age                  int64
# Education            int64
# Sale_target          int64
# Ord_Sheloc           int64
# US_No                uint8
# US_Yes               uint8
# Urban_No             uint8
# Urban_Yes            uint8
# dtype: object

# %% [markdown]
# # The Model
# The next part fits a random forest model to the data,

# %%
X_train, X_test, y_train, y_test = train_test_split(com_data.drop('Sale_target', 1), com_data['Sale_target'], test_size = .2, random_state=10)
#split t

# %%
model = DecisionTreeClassifier(criterion="entropy",max_depth=5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
#estimator = model.estimators_[1]
feature_names = [i for i in X_train.columns]

y_train_str = y_train.astype('str')
y_train_str[y_train_str == '0'] = 'low sale'
y_train_str[y_train_str == '1'] = 'high sale'
y_train_str = y_train_str.values

# %%
export_graphviz(model, out_file='tree.dot', 
                feature_names = feature_names,
                class_names = y_train_str,
                rounded = True, proportion = True, 
                label='root',
                precision = 2, filled = True)

from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree_sale_DT.png', '-Gdpi=600'])

from IPython.display import Image
Image(filename = 'tree_sale_DT.png')

# %% [markdown]
# This gives us on explainability tool. However, I can't glance at this and get a quick sense of the most important features of Company data set . We'll revisit those later. Next, let's evaluate the model,

# %%
y_predict = model.predict(X_test)
y_pred_quant = model.predict_proba(X_test)[:, 1]
y_pred_bin = model.predict(X_test)

# %%
confusion_matrix = confusion_matrix(y_test, y_pred_bin)
confusion_matrix
# Out:
# array([[39,  9],
#        [12, 20]], dtype=int64)

# %% [markdown]
# Sale evaluation  tests are often sold, marketed, cited and used with sensitivity and specificity as the headline metrics.

# %%
total=sum(sum(confusion_matrix))

sensitivity = confusion_matrix[0,0]/(confusion_matrix[0,0]+confusion_matrix[1,0])
print('Sensitivity : ', sensitivity )

specificity = confusion_matrix[1,1]/(confusion_matrix[1,1]+confusion_matrix[0,1])
print('Specificity : ', specificity)
# Out:
# Sensitivity :  0.7647058823529411
# Specificity :  0.6896551724137931

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_quant)

fig, ax = plt.subplots()
ax.plot(fpr, tpr)
ax.plot([0, 1], [0, 1], transform=ax.transAxes, ls="--", c=".3")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.rcParams['font.size'] = 12
plt.title('ROC curve for Sales classifier')
plt.xlabel('False Positive Rate (1 - Specificity)')
plt.ylabel('True Positive Rate (Sensitivity)')
plt.grid(True)

# %% [markdown]
# Another common metric is the Area Under the Curve, or AUC. This is a convenient way to capture the performance of a model in a single number, although it's not without certain issues. As a rule of thumb, an AUC can be classed as follows,
#  - 0.90 - 1.00 = excellent
#  - 80 - 0.90 = good
#  - 0.70 - 0.80 = fair
#  - .60 - 0.70 = poor
#  - 0.50 - 0.60 = fail
# Let's see what the above ROC gives us,

# %%
auc(fpr, tpr)
# Out:
# 0.7893880208333334

# %% [markdown]
# # The Explanation
#
# Now let's see what the model gives us from the ML explainability tools.
# Permutation importance * is the first tool for understanding a machine-learning model, and involves shuffling individual variables in the validation data (after a model has been fit), and seeing the effect on accuracy.

# %%
perm = PermutationImportance(model, random_state=1).fit(X_test, y_test)
eli5.show_weights(perm, feature_names = X_test.columns.tolist())
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1000
#
#                     &plusmn; 0.0447
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Ord_Sheloc
#             </td>
# ...

# %% [markdown]
# So, it looks like the most important factors in terms of permutation is a helf Location at stores high impact on sales. The high importance of 'Price rate achieved' type makes sense,  also Shelf Location at storesas this is the immediate, subjective state of the price at the time of Sales (as opposed to, say, Urban_Yes,Education which is a much more general factor).

# %%
base_features = com_data.columns.values.tolist()
base_features.remove('Sale_target')

feat_name = 'Price'
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=base_features, feature=feat_name)

pdp.pdp_plot(pdp_dist, feat_name)
plt.show()

# %%
feat_name = 'Ord_Sheloc'
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=base_features, feature=feat_name)

pdp.pdp_plot(pdp_dist, feat_name)
plt.show()

# %%
feat_name = 'Advertising'
pdp_dist = pdp.pdp_isolate(model=model, dataset=X_test, model_features=base_features, feature=feat_name)

pdp.pdp_plot(pdp_dist, feat_name)
plt.show()

# %%
from sklearn.metrics import classification_report, accuracy_score


print(classification_report(y_test, y_pred_bin))
print(" Accuracy of Model is : ",accuracy_score(y_test, y_pred_bin))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.79        48
#            1       0.69      0.62      0.66        32
#
#     accuracy                           0.74        80
#    macro avg       0.73      0.72      0.72        80
# weighted avg       0.73      0.74      0.74        80
#
#  Accuracy of Model is :  0.7375

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this Use case We have found that various factors which has affected the Sales of Company.
# - Price of product that has major impact on Sales.
# - Shelf Location at storesas
# - Advertisement is also play a vital role to affect the Sales of Organisation.
